# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaymaurya1/HP_AK/blob/main/VE_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas openpyxl xlrd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-375f0cb6-83fe-4bb4-b765-c55d50d90e74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-375f0cb6-83fe-4bb4-b765-c55d50d90e74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
data = pd.read_excel('test.xlsx')

# %%
data
# Out:
#              where to get          parameters   output
# 0            Design sheet         form_factor  4680.00
# 1            Design sheet    nominal_capacity    16.45
# 2            Design sheet    minimum_capacity    15.99
# 3            Design sheet     nominal_voltage     3.20
# 4            Design sheet      nominal_energy    52.70
# 5                 Testing          Cycle_life  4000.00
# 6                 Testing                dcir     3.00
# 7            Design sheet             weight    322.52
# 8            Design sheet      energy_density   163.25
# 9                 Testing     C_rate_charging     1.00
# 10                Testing  C_rate_discharging     1.00
# 11           Design sheet               V_max     3.60
# 12           Design sheet            V_cutoff     2.50
# 13                Testing                Tmax   -10.00
# 14                Testing                Tmin    60.00
# 15           Design sheet         nominal_dia    46.00
# ...

# %%
data.parameters
# Out:
# 0            form_factor
# 1       nominal_capacity
# 2       minimum_capacity
# 3        nominal_voltage
# 4         nominal_energy
# 5             Cycle_life
# 6                   dcir
# 7                weight
# 8         energy_density
# 9        C_rate_charging
# 10    C_rate_discharging
# 11                 V_max
# 12              V_cutoff
# 13                  Tmax
# 14                  Tmin
# 15           nominal_dia
# 16                height
# 17                safety
# Name: parameters, dtype: object

# %%
data.output
# Out:
# 0     4680.00
# 1       16.45
# 2       15.99
# 3        3.20
# 4       52.70
# 5     4000.00
# 6        3.00
# 7      322.52
# 8      163.25
# 9        1.00
# 10       1.00
# 11       3.60
# 12       2.50
# 13     -10.00
# 14      60.00
# 15      46.00
# 16      80.00
# 17       0.00
# Name: output, dtype: float64

# %%
# Assuming df is your DataFrame and "Parameters" and "Values" are the relevant columns

user = input()
data1 = data['output'][data['parameters'] == user].values[0]
print(data1)
# Out:
# weight
# 322.52

# %%
data1
# Out:
# 322.52

# %%
User = input()
